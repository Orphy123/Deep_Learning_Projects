# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/Orphy123/AITDeepLearning.git">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
from IPython.display import Image

# %%
Image(filename='images.jpeg')

# %%
from PIL import Image

# %%
im = Image.open("images.jpeg")
right_side = im.crop((im.width-30, 0, im.width, 30))
black = Image.new("RGB", right_30x30.size, "black")
im.paste(black, (im.width-30, 0))
im.save("newOne.jpg")

# %%
from IPython.display import Image
Image(filename='newOne.jpg')
